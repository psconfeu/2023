# %% [markdown]
# Now we will show a more obvious example of the performance cost of both the overhead involved in the formatting of the .NET objects, as well as leveraging the pipeline for gathering multiple pieces of information.
#
# We will compare running some simple commands interactively to a script which leverages `Get-View` to gather significantly more details.
#
# Let's start with connecting to our environment.

# %%
$vCenterServer = 'flashstack-vcenter.puretec.purestorage.com'
$vCenterUser= 'administrator@vsphere.local'
$vCenterCred = Get-Credential -UserName $vCenterUser
Connect-VIServer -Server $vCenterServer -Credential $vCenterCred -Protocol https -ErrorAction Stop

# %% [markdown]
# Now that we're connected, we will use `Get-VM` to return all virtual machines
#
# As this is intended to be an object returned to some expecting to see it as a typical PowerShell object, it will have a predefined set of properties returned.

# %%
$Stopwatch = [System.Diagnostics.Stopwatch]::new()
$Stopwatch.Start()

$VMs = Get-VM
$VMs | Get-Snapshot
$VMs | Get-HardDisk

$Stopwatch.Stop()
$Stopwatch.Elapsed.TotalSeconds
# Out:
# Name                 Description                    PowerState
# ----                 -----------                    ----------
# os-install                                          PoweredOff
# oracleasmsupport                                    PoweredOff
# before useradd                                      PoweredOff
# before nvme                                         PoweredOff
# after NVMe setup                                    PoweredOff
# P1                                                  PoweredOn
# p2                                                  PoweredOn
# os-install                                          PoweredOff
# oracleasmsupport                                    PoweredOn
# before useradd                                      PoweredOff
# before nvme                                         PoweredOff
# after NVMe setup                                    PoweredOff
# before grid install                                 PoweredOff
# P1                                                  PoweredOn
# p2                                                  PoweredOn
# OS install                                          PoweredOn
# after ansible                                       PoweredOn
# does successful                                     PoweredOn
# before vmagent                                      PoweredOff
# before                                              PoweredOff
# before fdisk                                        PoweredOn
# after prometheus                                    PoweredOff
# after grafana                                       PoweredOff
# after exporter                                      PoweredOff
# before nodeexporter                                 PoweredOff
# before pgexporter                                   PoweredOn
# Recovered - 4%2f12%…                                PoweredOn
# pre-install                                         PoweredOn
# ansible before                                      PoweredOn
# 4April                                              PoweredOff
# 29 May                                              PoweredOff
# 4April                                              PoweredOff
# 5th April                                           PoweredOff
# 20april                                             PoweredOff
# save from vijay                                     PoweredOff
# 4April                                              PoweredOff
# 5th April                                           PoweredOff
# 20april                                             PoweredOff
# save from vijay                                     PoweredOff
# 4april                                              PoweredOff
# 5th april                                           PoweredOff
# 20april                                             PoweredOff
# save from vijay                                     PoweredOff
# 4april                                              PoweredOff
#
# StorageFormat   : EagerZeroedThick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [dx-esxi-ds-temp] ubuntu-transfer-03/ubuntu-transfer-03.vmdk
# CapacityKB      : 62914560
# CapacityGB      : 60
# ParentId        : VirtualMachine-vm-1837
# Parent          : ubuntu-transfer-03
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1837/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1837/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [dx-esxi-ds-temp] ubuntu-transfer-big/ubuntu-transfer-big.vmdk
# CapacityKB      : 125829120
# CapacityGB      : 120
# ParentId        : VirtualMachine-vm-1838
# Parent          : ubuntu-transfer-big
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1838/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1838/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [dx-esxi-ds-temp] ubuntu-transfer-01/ubuntu-transfer-01.vmdk
# CapacityKB      : 62914560
# CapacityGB      : 60
# ParentId        : VirtualMachine-vm-1833
# Parent          : ubuntu-transfer-01
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1833/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1833/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [dx-esxi-ds-temp] ubuntu-transfer-02/ubuntu-transfer-02.vmdk
# CapacityKB      : 62914560
# CapacityGB      : 60
# ParentId        : VirtualMachine-vm-1836
# Parent          : ubuntu-transfer-02
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1836/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1836/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] orc-node2/orc-node2-000007.vmdk
# CapacityKB      : 262144000
# CapacityGB      : 250
# ParentId        : VirtualMachine-vm-804122
# Parent          : orc-node2
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804122/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804122/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] orc-node1/orc-node1-000008.vmdk
# CapacityKB      : 262144000
# CapacityGB      : 250
# ParentId        : VirtualMachine-vm-804121
# Parent          : orc-node1
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804121/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804121/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc]
#                   mssql-test-2.puretec.purestorage.com/mssql-test-2.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804111
# Parent          : mssql-test-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804111/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804111/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc]
#                   mssql-test-2.puretec.purestorage.com/mssql-test-2.puretec.purestorage.com_1.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804111
# Parent          : mssql-test-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804111/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804111/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-2.puretec.purestorage.com/oracle-ramarac2-2.pur
#                   etec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804105
# Parent          : oracle-ramarac2-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804105/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804105/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-2.puretec.purestorage.com/oracle-ramarac2-2.pur
#                   etec.purestorage.com_1.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804105
# Parent          : oracle-ramarac2-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804105/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804105/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-2.puretec.purestorage.com/oracle-ramarac2-2.pur
#                   etec.purestorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804105
# Parent          : oracle-ramarac2-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804105/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804105/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-2.puretec.purestorage.com/oracle-ramarac2-2.pur
#                   etec.purestorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804105
# Parent          : oracle-ramarac2-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804105/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804105/2003
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-2.puretec.purestorage.com/oracle-ramarac-2.puret
#                   ec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804075
# Parent          : oracle-ramarac-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804075/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804075/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-2.puretec.purestorage.com/oracle-ramarac-2.puret
#                   ec.purestorage.com_1.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804075
# Parent          : oracle-ramarac-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804075/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804075/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : IndependentPersistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804075
# Parent          : oracle-ramarac-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804075/HardDisk=2016/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804075/2016
# Name            : Hard disk 3
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : IndependentPersistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804075
# Parent          : oracle-ramarac-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804075/HardDisk=2017/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804075/2017
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-2.puretec.purestorage.com/oracle-ramarac-2.puret
#                   ec.purestorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804075
# Parent          : oracle-ramarac-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804075/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804075/2002
# Name            : Hard disk 5
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-2.puretec.purestorage.com/oracle-ramarac-2.puret
#                   ec.purestorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804075
# Parent          : oracle-ramarac-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804075/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804075/2003
# Name            : Hard disk 6
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-asm-4.puretec.purestorage.com/oracle-asm-4.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804073
# Parent          : oracle-asm-4.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804073/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804073/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-asm-4.puretec.purestorage.com/oracle-asm-4.puretec.purestorage.com_1.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804073
# Parent          : oracle-asm-4.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804073/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804073/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-asm-4.puretec.purestorage.com/oracle-asm-4.puretec.purestorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804073
# Parent          : oracle-asm-4.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804073/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804073/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-asm-4.puretec.purestorage.com/oracle-asm-4.puretec.purestorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804073
# Parent          : oracle-asm-4.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804073/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804073/2003
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-11.puretec.purestorage.com/postgres-11.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804072
# Parent          : postgres-11.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804072/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804072/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-11.puretec.purestorage.com/postgres-11.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804072
# Parent          : postgres-11.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804072/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804072/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-7.puretec.purestorage.com/postgres-7.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804069
# Parent          : postgres-7.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804069/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804069/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-7.puretec.purestorage.com/postgres-7.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804069
# Parent          : postgres-7.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804069/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804069/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-9.puretec.purestorage.com/postgres-9.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804067
# Parent          : postgres-9.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804067/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804067/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-9.puretec.purestorage.com/postgres-9.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804067
# Parent          : postgres-9.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804067/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804067/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-3.puretec.purestorage.com/postgres-3.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804066
# Parent          : postgres-3.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804066/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804066/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-3.puretec.purestorage.com/postgres-3.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804066
# Parent          : postgres-3.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804066/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804066/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-4.puretec.purestorage.com/postgres-4.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804065
# Parent          : postgres-4.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804065/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804065/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-4.puretec.purestorage.com/postgres-4.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804065
# Parent          : postgres-4.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804065/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804065/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-6.puretec.purestorage.com/postgres-6.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804064
# Parent          : postgres-6.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804064/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804064/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-6.puretec.purestorage.com/postgres-6.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804064
# Parent          : postgres-6.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804064/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804064/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-8.puretec.purestorage.com/postgres-8.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804068
# Parent          : postgres-8.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804068/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804068/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-8.puretec.purestorage.com/postgres-8.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804068
# Parent          : postgres-8.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804068/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804068/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc]
#                   mssql-test-1.puretec.purestorage.com/mssql-test-1.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-803136
# Parent          : mssql-test-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803136/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803136/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc]
#                   mssql-test-1.puretec.purestorage.com/mssql-test-1.puretec.purestorage.com_1.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-803136
# Parent          : mssql-test-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803136/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803136/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-2.puretec.purestorage.com/postgres-2.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-803307
# Parent          : postgres-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803307/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803307/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-2.puretec.purestorage.com/postgres-2.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-803307
# Parent          : postgres-2.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803307/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803307/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804074
# Parent          : oracle-ramarac-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804074/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804074/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_1.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804074
# Parent          : oracle-ramarac-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804074/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804074/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : IndependentPersistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804074
# Parent          : oracle-ramarac-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804074/HardDisk=2016/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804074/2016
# Name            : Hard disk 3
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : IndependentPersistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804074
# Parent          : oracle-ramarac-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804074/HardDisk=2017/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804074/2017
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_4.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804074
# Parent          : oracle-ramarac-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804074/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804074/2002
# Name            : Hard disk 5
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac-1.puretec.purestorage.com/oracle-ramarac-1.puret
#                   ec.purestorage.com_5.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804074
# Parent          : oracle-ramarac-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804074/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804074/2003
# Name            : Hard disk 6
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-5.puretec.purestorage.com/postgres-5.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804070
# Parent          : postgres-5.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804070/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804070/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   postgres-5.puretec.purestorage.com/postgres-5.puretec.purestorage.com_1.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804070
# Parent          : postgres-5.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804070/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804070/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : EagerZeroedThick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] cHANA-test/cHANA-test.vmdk
# CapacityKB      : 262144000
# CapacityGB      : 250
# ParentId        : VirtualMachine-vm-803288
# Parent          : cHANA-test
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803288/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803288/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc]
#                   jump-win-1.puretec.purestorage.com/jump-win-1.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804115
# Parent          : jump-win-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804115/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804115/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc]
#                   jump-win-1.puretec.purestorage.com/jump-win-1.puretec.purestorage.com_1.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804115
# Parent          : jump-win-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804115/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804115/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-1.puretec.purestorage.com/oracle-ramarac2-1.pur
#                   etec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804106
# Parent          : oracle-ramarac2-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804106/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804106/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-1.puretec.purestorage.com/oracle-ramarac2-1.pur
#                   etec.purestorage.com_1.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804106
# Parent          : oracle-ramarac2-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804106/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804106/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-1.puretec.purestorage.com/oracle-ramarac2-1.pur
#                   etec.purestorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804106
# Parent          : oracle-ramarac2-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804106/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804106/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-ramarac2-1.puretec.purestorage.com/oracle-ramarac2-1.pur
#                   etec.purestorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804106
# Parent          : oracle-ramarac2-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804106/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804106/2003
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] postgresdb-test_1/postgresdb-test-000001.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-1680
# Parent          : postgresdb-test
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1680/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1680/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] postgresdb-test_1/postgresdb-test_1-000001.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-1680
# Parent          : postgresdb-test
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1680/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1680/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-victoriametricslab/fs-victoriametricslab-000001.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-730
# Parent          : fs-victoriametricslab
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-730/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-730/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-victoriametricslab/fs-victoriametricslab_1-000001.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-730
# Parent          : fs-victoriametricslab
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-730/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-730/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-vm-1.puretec.purestorage.com/oracle-vm-1.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-803243
# Parent          : oracle-vm-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803243/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803243/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-vm-1.puretec.purestorage.com/oracle-vm-1.puretec.purestorage.com_1.vmdk
# CapacityKB      : 2147483648
# CapacityGB      : 2048
# ParentId        : VirtualMachine-vm-803243
# Parent          : oracle-vm-1.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-803243/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-803243/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod]
#                   oracle-test-3.puretec.purestorage.com/oracle-test-3.puretec.purestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804041
# Parent          : oracle-test-3.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804041/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804041/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-test-3.puretec.purestorage.com/oracle-test-3.puretec.pur
#                   estorage.com_1.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804041
# Parent          : oracle-test-3.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804041/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804041/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-test-3.puretec.purestorage.com/oracle-test-3.puretec.pur
#                   estorage.com_2.vmdk
# CapacityKB      : 524288000
# CapacityGB      : 500
# ParentId        : VirtualMachine-vm-804041
# Parent          : oracle-test-3.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804041/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804041/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-test-3.puretec.purestorage.com/oracle-test-3.puretec.pur
#                   estorage.com_3.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-804041
# Parent          : oracle-test-3.puretec.purestorage.com
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804041/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804041/2003
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod02] Ansible-simran-target-Do Not
#                   Delete/Ansible-simran-target-Do Not Delete.vmdk
# CapacityKB      : 41943040
# CapacityGB      : 40
# ParentId        : VirtualMachine-vm-804047
# Parent          : Ansible-simran-target-Do Not Delete
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804047/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804047/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod02] Ansible-simran-target-Do Not
#                   Delete/Ansible-simran-target-Do Not Delete_1.vmdk
# CapacityKB      : 52428800
# CapacityGB      : 50
# ParentId        : VirtualMachine-vm-804047
# Parent          : Ansible-simran-target-Do Not Delete
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804047/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804047/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] oracle-test-1.puretec.purestorage.com_1/oracle-test-1.puretec.p
#                   urestorage.com.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-804042
# Parent          : oracle-test-1.puretec.purestorage.com
# ...
# CapacityKB      : 419430400
# CapacityGB      : 400
# ParentId        : VirtualMachine-vm-1841
# Parent          : VBRReady
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1841/HardDisk=2018/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1841/2018
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod02] VBRReady/VBRReady_2.vmdk
# CapacityKB      : 314572800
# CapacityGB      : 300
# ParentId        : VirtualMachine-vm-1841
# Parent          : VBRReady
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1841/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1841/2000
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod02] ubuntudev-aditya/ubuntudev-aditya.vmdk
# CapacityKB      : 41943040
# CapacityGB      : 40
# ParentId        : VirtualMachine-vm-469
# Parent          : ubuntudev-aditya
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-469/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-469/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod01] ubuntudev-joe/ubuntudev-joe.vmdk
# CapacityKB      : 62914560
# CapacityGB      : 60
# ParentId        : VirtualMachine-vm-61
# Parent          : ubuntudev-joe
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-61/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-61/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] VBR-anjali/VBR-anjali.vmdk
# CapacityKB      : 314572800
# CapacityGB      : 300
# ParentId        : VirtualMachine-vm-1374
# Parent          : VBR-anjali
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1374/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1374/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] Veeamtest1-anjali/Veeamtest1-anjali.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-213
# Parent          : vbr-anj
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-213/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-213/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod01] Rama-Win-Jump/Rama-Win-Jump.vmdk
# CapacityKB      : 94371840
# CapacityGB      : 90
# ParentId        : VirtualMachine-vm-804108
# Parent          : Rama-Win-Jump
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804108/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804108/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod01] Rama-Linux-Jump/Rama-Linux-Jump.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804107
# Parent          : Rama-Linux-Jump
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804107/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804107/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] nvmetest/nvmetest.vmdk
# CapacityKB      : 209715200
# CapacityGB      : 200
# ParentId        : VirtualMachine-vm-804050
# Parent          : nvmetest
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-804050/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-804050/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] Test-JmpWin/Test-JmpWin.vmdk
# CapacityKB      : 94371840
# CapacityGB      : 90
# ParentId        : VirtualMachine-vm-157
# Parent          : Test-JmpWin
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-157/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-157/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] Jumpbox-AG/Jumpbox-AG.vmdk
# CapacityKB      : 94371840
# CapacityGB      : 90
# ParentId        : VirtualMachine-vm-200
# Parent          : Jumpbox-AG
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-200/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-200/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] fs-linjmp01/fs-linjmp01-000001.vmdk
# CapacityKB      : 104857600
# CapacityGB      : 100
# ParentId        : VirtualMachine-vm-201
# Parent          : fs-linjmp01
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-201/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-201/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] FS-WinJmp1/FS-WinJmp1-000002.vmdk
# CapacityKB      : 94371840
# CapacityGB      : 90
# ParentId        : VirtualMachine-vm-161
# Parent          : FS-WinJmp1
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-161/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-161/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] FS-WinJmp1/FS-WinJmp1_1-000001.vmdk
# CapacityKB      : 157286400
# CapacityGB      : 150
# ParentId        : VirtualMachine-vm-161
# Parent          : FS-WinJmp1
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-161/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-161/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] Aditya-jumpbox/Aditya-jumpbox.vmdk
# CapacityKB      : 94371840
# CapacityGB      : 90
# ParentId        : VirtualMachine-vm-198
# Parent          : Aditya-jumpbox
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-198/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-198/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vidm/fs-vidm-000004.vmdk
# CapacityKB      : 62914560
# CapacityGB      : 60
# ParentId        : VirtualMachine-vm-1756
# Parent          : fs-vidm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1756/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1756/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vidm/fs-vidm_1-000004.vmdk
# CapacityKB      : 20971520
# CapacityGB      : 20
# ParentId        : VirtualMachine-vm-1756
# Parent          : fs-vidm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1756/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1756/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vidm/fs-vidm_2-000004.vmdk
# CapacityKB      : 20971520
# CapacityGB      : 20
# ParentId        : VirtualMachine-vm-1756
# Parent          : fs-vidm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1756/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1756/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [Metro_Cluster1_Prod02] AnsibleSim/AnsibleSim.vmdk
# CapacityKB      : 41943040
# CapacityGB      : 40
# ParentId        : VirtualMachine-vm-1569
# Parent          : AnsibleSim
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1569/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1569/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] fs-vrlscm/fs-vrlscm-000004.vmdk
# CapacityKB      : 10485760
# CapacityGB      : 10
# ParentId        : VirtualMachine-vm-185
# Parent          : fs-vrlscm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-185/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-185/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] fs-vrlscm/fs-vrlscm_1-000004.vmdk
# CapacityKB      : 83886080
# CapacityGB      : 80
# ParentId        : VirtualMachine-vm-185
# Parent          : fs-vrlscm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-185/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-185/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] fs-vrlscm/fs-vrlscm_2-000004.vmdk
# CapacityKB      : 10485760
# CapacityGB      : 10
# ParentId        : VirtualMachine-vm-185
# Parent          : fs-vrlscm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-185/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-185/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Misc] fs-vrlscm/fs-vrlscm_3-000004.vmdk
# CapacityKB      : 8388608
# CapacityGB      : 8
# ParentId        : VirtualMachine-vm-185
# Parent          : fs-vrlscm
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-185/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-185/2003
# Name            : Hard disk 4
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vra/fs-vra-000004.vmdk
# CapacityKB      : 52428800
# CapacityGB      : 50
# ParentId        : VirtualMachine-vm-1757
# Parent          : fs-vra
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1757/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1757/2000
# Name            : Hard disk 1
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vra/fs-vra_1-000004.vmdk
# CapacityKB      : 150994944
# CapacityGB      : 144
# ParentId        : VirtualMachine-vm-1757
# Parent          : fs-vra
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1757/HardDisk=2001/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1757/2001
# Name            : Hard disk 2
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vra/fs-vra_2-000004.vmdk
# CapacityKB      : 23068672
# CapacityGB      : 22
# ParentId        : VirtualMachine-vm-1757
# Parent          : fs-vra
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1757/HardDisk=2002/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1757/2002
# Name            : Hard disk 3
#
#
# StorageFormat   : Thin
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack-Prod] fs-vra/fs-vra_3-000004.vmdk
# CapacityKB      : 31457280
# CapacityGB      : 30
# ParentId        : VirtualMachine-vm-1757
# Parent          : fs-vra
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-1757/HardDisk=2003/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-1757/2003
# Name            : Hard disk 4
#
#
# StorageFormat   : Thick
# Persistence     : Persistent
# DiskType        : Flat
# Filename        : [FlashStack_ISO_ContLib] fslab-ad/fslab-ad-000001.vmdk
# CapacityKB      : 94371840
# CapacityGB      : 90
# ParentId        : VirtualMachine-vm-160
# Parent          : fslab-ad
# Uid             : /VIServer=vsphere.local\administrator@flashstack-vcenter.puretec.purestorage.com:
#                   443/VirtualMachine=VirtualMachine-vm-160/HardDisk=2000/
# ConnectionState :
# ExtensionData   : VMware.Vim.VirtualDisk
# Id              : VirtualMachine-vm-160/2000
# Name            : Hard disk 1
#
# 5.6403158

# %% [markdown]
# For comparison, we will gather many more properties from the `Extension Data` properties of all of our virtual machines, and we will see how much more efficiently we can gather information without multiple cmdlets being run, along with no pipelines.
#
# For more information on the details gathered, check the code within the `../DemoCode/Get-VMData.ps1` file.

# %%
../DemoCode/Get-VMData.ps1

$Stopwatch = [System.Diagnostics.Stopwatch]::new()
$Stopwatch.Start()

Get-VMData

$Stopwatch.Stop()
$Stopwatch.Elapsed.TotalSeconds
# Out:
# 0.8227414
